# %%
import control as ct
import matplotlib.pyplot as plt
import numpy as np

# %%
# Define Transfer Function G(s) = (s + 1) / (s^4 + 4s^3 + 7s^2 + 6s + 3)
num = [1, 1]
den = [1, 4, 7, 6, 3]
G = ct.TransferFunction(num, den)

# %%
# Performance Metrics
info = ct.step_info(G)
poles = ct.poles(G)
zeros = ct.zeros(G)

# %%
print(f"Poles: {poles}")
print(f"Zeros: {zeros}")
print(f"Rise Time: {info['RiseTime']:.4f} s")
print(f"Settling Time (2%): {info['SettlingTime']:.4f} s")
print(f"Overshoot: {info['Overshoot']:.4f} %")
# Out:
# Poles: [-1.5+0.8660254j -1.5-0.8660254j -0.5+0.8660254j -0.5-0.8660254j]
# Zeros: [-1.+0.j]
# Rise Time: 1.4639 s
# Settling Time (2%): 8.6004 s
# Overshoot: 24.2262 %

# %%
# Visualization
plt.figure(figsize=(12, 10))

# %%
# Step Response
plt.subplot(2, 2, 1)
t, y = ct.step_response(G)
plt.plot(t, y)
plt.title('Step Response')
plt.grid(True)

# %%
# Bode Plot
plt.subplot(2, 2, 2)
ct.bode_plot(G)
plt.subplot(2, 2, 3) # Note: bode_plot handles subplots internally in some versions
# Out:
# <Axes: >

# %%
# Pole-Zero Map
plt.subplot(2, 2, 4)
ct.pzmap(G)
plt.show()
